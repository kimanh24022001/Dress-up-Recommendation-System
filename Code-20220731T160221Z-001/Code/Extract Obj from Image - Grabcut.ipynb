# %% [markdown]
# # **KHAI BÁO CÁC THƯ VIỆN CẦN THIẾT**

# %%
import numpy
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-acb60498-a5d7-426e-8381-12ff9ad473b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acb60498-a5d7-426e-8381-12ff9ad473b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1670.jpg to 1670.jpg

# %%
name = uploaded.keys()
filename = next(iter(uploaded))
filename
# Out:
# '1670.jpg'

# %%
img = cv.imread(filename, cv.IMREAD_UNCHANGED)
#cv2_imshow(img)
img[:,:,3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f8498f70e213> in <module>()
# ----> 1 img = cv.imread(filename, cv.IMREAD_UNCHANGED)
#       2 #cv2_imshow(img)
#       3 img[:,:,3]
#
# NameError: name 'cv' is not defined
